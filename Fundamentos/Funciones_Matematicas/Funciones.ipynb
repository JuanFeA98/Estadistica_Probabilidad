# %% [markdown]
# ## **Librerias**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = False

# %% [markdown]
# ## **1. Funciones Algebraicas**

# %% [markdown]
# ### **1.1 Función Lineal**

# %%
N = 100
pendiente = 2
corte = 4

X = np.linspace(-10, 10, num=N)

# %%
def funcion_lineal(x):
    return ((pendiente*(x))+corte)

# %%
y = [funcion_lineal(i) for i in X]

# %%
fig, ax = plt.subplots(figsize=(13, 4))
fig.patch.set_facecolor('#21252b') 

ax.plot(X,y)
ax.set_facecolor('#21252b') 

plt.xticks(fontsize=10, color='white', weight=100)
plt.yticks(fontsize=10, color='white', weight=100)
plt.grid(linewidth=0.1)

plt.show()

# %% [markdown]
# ### **1.2 Funciones Polinomicas**

# %%
def funcion_polinomica(x):
    return ((2*(x**7)) - (x**4) + (3*(x**2)) + 4)

# %%
values = [funcion_polinomica(i) for i in X]

# %%
fig, ax = plt.subplots(figsize=(15, 5))
fig.patch.set_facecolor('#21252b') 

plt.plot(X, values)
ax.set_facecolor('#21252b') 

plt.xticks(fontsize=10, color='white', weight=100)
plt.yticks(fontsize=10, color='white', weight=100)
plt.grid(linewidth=0.1)

plt.show()

# %% [markdown]
# ## **2. Funciones Trascendentes**

# %% [markdown]
# ### **2.1 Funciones Trigonométricas**

# %%
def funcion_seno(x):
    return np.sin(x)

def funcion_coseno(x):
    return np.cos(x)

def funcion_tangente(x):
    return np.tan(x)

# %%
values_sen = [funcion_seno(i) for i in X]
values_cos = [funcion_coseno(i) for i in X]
values_tan = [funcion_tangente(i) for i in X]

# %%
fig, ax = plt.subplots(figsize=(15, 4))
fig.patch.set_facecolor('#21252b') 

plt.plot(X, values_sen)
plt.plot(X, values_cos)

ax.set_facecolor('#21252b') 

plt.xticks(fontsize=10, color='white', weight=100)
plt.yticks(fontsize=10, color='white', weight=100)
plt.grid(linewidth=0.1)

plt.legend(['Seno', 'Coseno'], facecolor='#21252b', labelcolor='white', fontsize=12)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 4))
fig.patch.set_facecolor('#21252b') 

plt.plot(X, values_tan)

ax.set_facecolor('#21252b') 

plt.xticks(fontsize=10, color='white', weight=100)
plt.yticks(fontsize=10, color='white', weight=100)
plt.grid(linewidth=0.1)

plt.legend(['Tangente'], facecolor='#21252b', labelcolor='white', fontsize=13)
plt.show()

# %% [markdown]
# ### **2.2 Funciones Exponenciales**

# %%
def funcion_exponencial(x):
    return round(np.exp(x), 2)

# %%
values_exp = [funcion_exponencial(i) for i in X]

# %%
fig, ax = plt.subplots(figsize=(14, 5))
plt.plot(X, values_exp)

ax.set_facecolor('#21252b') 

plt.xticks(fontsize=10, color='white', weight=100)
plt.yticks(fontsize=10, color='white', weight=100)

plt.grid(linewidth=0.1)

plt.legend(['Función exponencial'], facecolor='#21252b',labelcolor='white', fontsize=12)

plt.show()

# %% [markdown]
# ### **2.3 Funciones Logarimicas**

# %%
def funcion_logaritmica(x):
    return round(np.log2(x), 2)

# %%
X = np.linspace(1, 10, 100)
values_log = [funcion_logaritmica(i) for i in X]

# %%
fig, ax = plt.subplots(figsize=(14, 5))

plt.plot(X, values_log)

ax.set_facecolor('#21252b') 

plt.xticks(fontsize=10, color='white', weight=100)
plt.yticks(fontsize=10, color='white', weight=100)

plt.grid(linewidth=0.1)
plt.legend(['Función logaritmica'], facecolor='#21252b', labelcolor='white', fontsize=12)

plt.show()

# %% [markdown]
# ## **3. Funciones Seccionadas**

# %%
X = np.linspace(-10, 10, num=N)

# %%
def funcion_seccionada(x):
    if x<0:
        return 0
    else:
        return 1

# %%
val_secc = [funcion_seccionada(i) for i in X]

# %%
fig, ax = plt.subplots(figsize=(14,5))

plt.scatter(X, val_secc)
ax.set_facecolor('#21252b') 

plt.xticks(fontsize=10, color='white', weight=100)
plt.yticks(fontsize=10, color='white', weight=100)

plt.grid(linewidth=0.1)
plt.legend(['Función seccionada'], facecolor='#21252b', labelcolor='white', fontsize=12)

plt.show()

# %% [markdown]
# ## **4. Funciones Compuestas**

# %%
def f(x):
    return np.sin(x)

# %%
def g(x):
    return x**2

# %%
val_g = [f(g(i)) for i in X]

# %%
fig, ax = plt.subplots(figsize=(14, 5))

plt.plot(X, val_g)
ax.set_facecolor('#21252b') 

plt.xticks(fontsize=10, color='white', weight=100)
plt.yticks(fontsize=10, color='white', weight=100)

plt.grid(linewidth=0.1)
plt.legend(['Función Compuesta'], facecolor='#21252b', labelcolor='white', fontsize=12, loc='lower left')

plt.show()

# %% [markdown]
# ## **5. Manipular Funciones**

# %% [markdown]
# ### **5.1 Desplazamientos**

# %%
val_1 = [g(i) for i in X]
val_2 = [g(i) + 20 for i in X]
val_3 = [g(i) - 20 for i in X]
val_4 = [g(i + 4) for i in X]
val_5 = [g(i - 4) for i in X]

# %%
fig, ax = plt.subplots(figsize=(14, 5))

plt.plot(X, val_1)
plt.plot(X, val_2)
plt.plot(X, val_3)
plt.plot(X, val_4)
plt.plot(X, val_5)

ax.set_facecolor('#21252b') 

ax.axhline(y=0, color='white')
ax.axvline(x=0, color='white')

plt.xticks(fontsize=10, color='white', weight=100)
plt.yticks(fontsize=10, color='white', weight=100)

plt.grid(linewidth=0.1)
plt.legend(
    [
        'Función Original', 
        'Desp hacia arriba',
        'Desp hacia abajo',
        'Desp hacia la izq',
        'Desp hacia la der'
    ], 
    facecolor='#21252b', 
    labelcolor='white', 
    fontsize=12, 
    loc='lower left')

plt.show()

# %% [markdown]
# ### **5.2 Alargamientos y compresiones**

# %%
val_1 = [f(i) for i in X]
val_2 = [5 * f(i) for i in X]
val_3 = [f(i)/3 for i in X]
val_4 = [f(i*5) for i in X]
val_5 = [f(i/3) for i in X]

# %%
fig, ax = plt.subplots(figsize=(14, 5))

plt.plot(X, val_1)
plt.plot(X, val_2)
plt.plot(X, val_3)
plt.plot(X, val_4)
plt.plot(X, val_5)

ax.set_facecolor('#21252b') 

ax.axhline(y=0, color='white')
ax.axvline(x=0, color='white')

plt.xticks(fontsize=10, color='white', weight=100)
plt.yticks(fontsize=10, color='white', weight=100)

plt.grid(linewidth=0.1)
plt.legend(
    [
        'Función Original', 
        'Comprimida Vert',
        'Alargada Vert',
        'Comprimida Hor',
        'Alargada Hor'
    ], 
    facecolor='#21252b', 
    labelcolor='white', 
    fontsize=12, 
    loc='lower left')

plt.show()

# %% [markdown]
# ### **5.3 Reflexiones**

# %%
val_pol_1 = [g(i) for i in X]
val_pol_2 = [g(i) * -1 for i in X]
val_pol_3 = [g(i*-1) for i in X]

# %%
fig, ax = plt.subplots(figsize=(14, 5))

plt.plot(X, val_pol_1)
plt.plot(X, val_pol_2)
plt.plot(X, val_pol_3)

ax.set_facecolor('#21252b') 

plt.xticks(fontsize=10, color='white', weight=100)
plt.yticks(fontsize=10, color='white', weight=100)

plt.legend(
    [
        'Función Original', 
        'Función reflectada Hor',
        'Función reflectada Vert'
    ], 
    facecolor='#21252b', 
    labelcolor='white', 
    fontsize=12, 
    loc='lower left')


plt.grid(linewidth=0.1)
plt.show()
